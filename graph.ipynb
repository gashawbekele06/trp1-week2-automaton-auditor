# %%
# test_send.py
from langgraph.types import Send

print("Send imported OK:", Send)
print("You can now use Send() for fan-out")
# Out:
# Send imported OK: <class 'langgraph.types.Send'>
# You can now use Send() for fan-out

# %%
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from src.state import AgentState
from src.nodes.setup import setup_node
from src.nodes.detectives import detectives_node
# ... other imports ...
# Out:
# Traceback (most recent call last):
#
#   File ~/Desktop/TRP1/trp1-week2-automaton-auditor/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3701 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[7], line 5
#     from src.nodes.setup import setup_node
#
#   File ~/Desktop/TRP1/trp1-week2-automaton-auditor/src/nodes/setup.py:5
#     from src.tools.repo_tools import safe_git_clone
#
#   File ~/Desktop/TRP1/trp1-week2-automaton-auditor/src/tools/repo_tools.py:36
#     for line in lines if line:
#                              ^
# SyntaxError: invalid syntax
